# %%
print("hello,world")
# Out:
# hello,world

# %%
print("tarun")
# Out:
# tarun

# %%
print ('tarun')
# Out:
# tarun

# %%
2+3
# Out:
# 5

# %%
x=1

# %%
x=10
y="varma"
print(x)
print(y)
# Out:
# 10
# varma

# %%
x=int(3)
z=str(3)
y=float(3)
print(z)
print(x)
print(y)
# Out:
# 3
# 3
# 3.0

# %%
x=10

print(type(x))
x="varma"
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x="varma"
x='john'
x=1
print(x)
# Out:
# 1

# %%
a,b,c,d,e,f,g="seven","seven","seven","seven","seven","seven","seven"
print(a,b,c,d,e,f,g)
# Out:
# seven seven seven seven seven seven seven

# %%
a=b=c=d=e=f=g="seven"
print(a,b,c,d,e,f,g)
# Out:
# seven seven seven seven seven seven seven

# %%
fruit=["banana","apple","mango"]
print(fruit)
x,y,z=fruit
print(x)
print(y)
print(z)
# Out:
# ['banana', 'apple', 'mango']
# banana
# apple
# mango

# %% [markdown]
# tuple,
# set,
# dictionaries,
# conditional statements

# %%
thistuple = ("apple", "banana", "cherry","mango","pineapple","kivi")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'mango', 'pineapple', 'kivi')

# %%
set = {"apple", "banana", "cherry","true",1,2,3}
print(set)
# Out:
# {1, 2, 3, 'cherry', 'banana', 'true', 'apple'}

# %%
thisdict = {
  "brand": "kia",
  "model": "seltos",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'kia', 'model': 'seltos', 'year': 1964}

# %%
x="python"
y="is"
z="awsome"
print(x,y,z)
# Out:
# python is awsome

# %%
x="python"
y="is"
z="awsome"
print(x+y+z)
# Out:
# pythonisawsome

# %%
x="python "
y="is "
z="awsome "
print(x+y+z)
# Out:
# python is awsome

# %%
import sys as tarun
print(tarun.version)
# Out:
# 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]

# %%
if 5 > 8:
  print("five greater than two")
print("it does not belongs to if condition")
# Out:
# it does not belongs to if condition

# %%
if 5 > 8:
  print("five greater than two")
else :
    print("it does not belongs to if condition")
# Out:
# it does not belongs to if condition

# %%
if 5 > 2:
  print("five greater than two")
  if 5 > 3:
     print("true")
else :
    print("it does not belongs to if condition")
# Out:
# five greater than two
# true

# %%
 a=10
 b=5
 if a > b:
  print("a greater than b")
 elif a == b:
  print("a equals to b")
# Out:
# a greater than b

# %%
i = 0
while i < 6:
  print(i)
  i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
fruits = ["banana","apple","mango"]
for x in fruits:
  print(x)
# Out:
# banana
# apple
# mango

# %%
# Create a graph given in the above diagram.
graph = {
    'A': ['B', 'C', 'D'],    'B': ['A'],
    'C': ['A', 'D'],    'D': ['A', 'C', 'E'],
    'E': ['D'],
    }
# to print a BFS of a graph
def bfs(node):
    # mark vertices as False means not visited
    visited = [False] * (len(graph))
    # make an empty queue for bfs
    queue = []
    # mark gave node as visited and add it to the queue
    visited.append(node)
    queue.append(node)
    while queue:
        # Remove the front vertex or the vertex at the 0th index from the queue and print that vertex.
        v = queue.pop(0)
        print(v ,end=" ")
        # Get all adjacent nodes of the removed node v from the graph hash table.        # If an adjacent node has not been visited yet,
        # then mark it as visited and add it to the queue.
        for neigh in graph[v]:
            if neigh not in visited:
              visited.append(neigh)
              queue.append(neigh)
# Driver Code
if __name__ == "__main__":
  bfs('A')
# Out:
# A B C D E

# %%
from matplotlib import pyplot as plt
plt.plot([2,0,0,6],[2,0,0,5])
plt.show()

# %%
from matplotlib import pyplot as plt
x=[2,0,0,5]
y=[2,0,0,6]
plt.plot(x,y)
plt.title('info')
plt.ylabel('y-axis')
plt.xlabel('x-axis')
plt.show()

# %%
x = [2,0,0,6]
y = [1,9,7,8]
plt.plot(x, y)
plt.xlabel('The x label')
plt.ylabel('The y label')
plt.title('A matplotlib plot', fontproperties = font_0, fontsize = 15, loc = 'left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ce5602f99e63> in <cell line: 6>()
#       4 plt.xlabel('The x label')
#       5 plt.ylabel('The y label')
# ----> 6 plt.title('A matplotlib plot', fontproperties = font_0, fontsize = 15, loc = 'left')
#
# NameError: name 'font_0' is not defined
